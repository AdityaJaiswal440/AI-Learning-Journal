# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'color' : ['red','blue','green','green','red','blue']
})

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl_encoder = LabelEncoder()

# %%
import numpy as np

# %%
lbl_encoder.fit_transform(df[['color']])
# Out:
# c:\Users\jaisw\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([2, 0, 1, 1, 2, 0])

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'size' : ['small','medium','large','medium','small','large']
})

# %%
encoder = OrdinalEncoder(categories=[['small','medium','large']])

# %%
encoder.fit_transform(df[['size']])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.]])

# %%
encoder.transform([['small']])
# Out:
# c:\Users\jaisw\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([[0.]])

# %%
import pandas as pd

df = pd.DataFrame({
    'city' : ['New York','London','Paris','Tokyo','New York','Paris'],
    'price' : [200,150,300,350,100,250]
})

# %%
df
# Out:
#        city  price
# 0  New York    200
# 1    London    150
# 2     Paris    300
# 3     Tokyo    350
# 4  New York    100
# 5     Paris    250

# %%
mean_price = df.groupby('city')['price'].mean().to_dict()

# %%
mean_price
# Out:
# {'London': 150.0, 'New York': 150.0, 'Paris': 275.0, 'Tokyo': 350.0}

# %%
df['city_encoded'] = df['city'].map(mean_price)

# %%
df
# Out:
#        city  price  city_encoded
# 0  New York    200         150.0
# 1    London    150         150.0
# 2     Paris    300         275.0
# 3     Tokyo    350         350.0
# 4  New York    100         150.0
# 5     Paris    250         275.0

# %%
df[['price','city_encoded']]
# Out:
#    price  city_encoded
# 0    200         150.0
# 1    150         150.0
# 2    300         275.0
# 3    350         350.0
# 4    100         150.0
# 5    250         275.0
