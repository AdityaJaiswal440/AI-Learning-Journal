# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000,n_features=2,n_classes=2,n_clusters_per_class=1,n_redundant=0)

# %%
X
# Out:
# array([[ 0.38096176,  0.17806497],
#        [-0.73666181, -0.47543147],
#        [ 1.1537849 ,  0.204293  ],
#        ...,
#        [-2.10276599,  1.41767137],
#        [ 0.24365757, -0.78812379],
#        [ 0.03996307,  0.74687454]], shape=(1000, 2))

# %%
pd.DataFrame(X)
# Out:
#             0         1
# 0    0.380962  0.178065
# 1   -0.736662 -0.475431
# 2    1.153785  0.204293
# 3   -2.683992  1.447521
# 4   -0.724408 -1.173710
# ..        ...       ...
# 995 -1.038799 -1.451839
# 996 -1.960786  1.402275
# 997 -2.102766  1.417671
# 998  0.243658 -0.788124
# 999  0.039963  0.746875
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(x=pd.DataFrame(X)[0],y=pd.DataFrame(X)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import train_test_split

# %%
svc=SVC()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
score = accuracy_score(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)
print(score)
print(cm)
print(classification_report(y_test,y_pred))
# Out:
# 0.968
# [[114   5]
#  [  3 128]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       119
#            1       0.96      0.98      0.97       131
#
#     accuracy                           0.97       250
#    macro avg       0.97      0.97      0.97       250
# weighted avg       0.97      0.97      0.97       250

# %%
svc.intercept_
# Out:
# array([0.27201899])
